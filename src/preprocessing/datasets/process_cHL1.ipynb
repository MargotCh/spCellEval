# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import anndata as ad

# %%
sc._settings.ScanpyConfig.n_jobs = -1

# %%
def z_score_normalization(data):
    return (data - np.mean(data, axis=0)) / np.std(data, axis=0)

def reorder_columns(df, col_changed, col_position) -> pd.DataFrame:
    """
    Reordering colums. The second input can either be an integer for index or it can be a reference column name. If reference column name is chosen, the column will be placed after the reference column.
    """
    if not isinstance(df, pd.DataFrame):
        raise ValueError("The first argument must be a pandas DataFrame")
    if not isinstance(col_changed, str):
        raise ValueError("The second argument must be a string representing a column name")
    if not isinstance(col_position, (str, int)):
        raise ValueError("The third argument must be either a string representing a column name or an integer representing a column index")
    if isinstance(col_position, int):
        cols = df.columns.tolist()
        if col_changed in cols and col_position <= len(cols) + 1:
            cols.remove(col_changed)
        
            index = col_position
            cols.insert(index, col_changed)
            
            df = df[cols]
    else:
        cols = df.columns.tolist()
        if col_changed in cols and col_position in cols:
            cols.remove(col_changed)
            index = cols.index(col_position)
            cols.insert(index+1, col_changed)
            
            df = df[cols]
    return df

# %%
df = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets2/cHL_1_MIBI/quantification/cHL1_MIBI.csv')

# %%
df = reorder_columns(df, 'cellLabel', 'identifier')
df = reorder_columns(df, 'Annotation', 'cellLabel')
df.rename(columns={'Annotation': 'cell_type', 'centroidX':'x', 'centroidY': 'y'}, inplace=True)
df = reorder_columns(df, 'y', 'cellSize')
df = reorder_columns(df, 'x', 'cellSize')

# %%
df.columns

# %%
df.to_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/cHL1_MIBI_cleaned.csv', index=False)

# %%
df

# %%
X_columns = df.columns[:df.columns.get_loc('cellSize')]
obs_columns = df.columns[df.columns.get_loc('cellSize'):]
adata = ad.AnnData(
    X=df[X_columns],
    obs=df[obs_columns],
    var=pd.DataFrame(index=X_columns)
)
# Out:
# /Users/lukashat/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.raw = adata
adata.X = np.arcsinh(adata.X)
adata.layers['zscore'] = z_score_normalization(adata.X)

# %%
sc.pp.neighbors(adata, n_neighbors=10)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='cell_type')

# %%
sc.pl.matrixplot(adata, var_names=adata.var_names, groupby='cell_type', cmap='vlag', dendrogram=True, use_raw=False, standard_scale='var')

# %%
sc.tl.rank_genes_groups(adata, groupby='cell_type' , method='wilcoxon')

# %%
sc.tl.filter_rank_genes_groups(adata, min_in_group_fraction=0.2, max_out_group_fraction = 1, key = 'rank_genes_groups', key_added='rank_genes_groups_filtered')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=5, standard_scale='var', key='rank_genes_groups')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=5, standard_scale='var', key='rank_genes_groups_filtered')

# %% [markdown]
# ## Harmonize celltype labels

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv')
df
# Out:
#              CD45      CD20     CD163  Histone H3    CD45RO      CD28  \
# 0        0.001217  0.016976  0.131463    0.192797  0.001151  0.000207
# 1        0.000000  0.000000  0.024141    0.202666  0.000945  0.000000
# 2        0.000451  0.000000  0.040998    0.051099  0.003537  0.000000
# 3        0.000000  0.000000  0.159136    0.057322  0.000526  0.000000
# 4        0.000000  0.000000  0.117901    0.072533  0.003073  0.000000
# ...           ...       ...       ...         ...       ...       ...
# 1669848  0.000345  0.000000  0.002531    0.196096  0.001716  0.000462
# 1669849  0.000205  0.000000  0.000139    0.184302  0.001173  0.000058
# 1669850  0.000812  0.000608  0.000000    0.179846  0.001337  0.000555
# 1669851  0.000000  0.000000  0.000000    0.080264  0.000978  0.000000
# 1669852  0.000000  0.000540  0.000000    0.196379  0.001064  0.000039
#
#          CD153 (CD30L)      Lag3       CD4     CD11c  ...      CD25  \
# 0             0.000074  0.000160  0.001707  0.000000  ...  0.001094
# 1             0.000000  0.000112  0.000000  0.000000  ...  0.000030
# 2             0.000000  0.000000  0.002056  0.000000  ...  0.001518
# 3             0.000000  0.000000  0.000156  0.000000  ...  0.000939
# 4             0.000000  0.000000  0.000000  0.000000  ...  0.001069
# ...                ...       ...       ...       ...  ...       ...
# 1669848       0.002012  0.000046  0.006395  0.005166  ...  0.000953
# 1669849       0.006320  0.000045  0.000000  0.000000  ...  0.000344
# 1669850       0.002020  0.000016  0.003382  0.000000  ...  0.000809
# 1669851       0.001857  0.000000  0.000000  0.000000  ...  0.000022
# 1669852       0.001364  0.000000  0.003807  0.000296  ...  0.000554
#
#          Na-K ATPase  cellSize     x     y  sample_id  cell_id  \
# 0           0.003093       249   559  1996         31    26325
# 1           0.001797        22  1406     3         31        5
# 2           0.005575        35  1502     4         31        7
# 3           0.004156        29  1838     4         31        8
# 4           0.008932        14  2027     3         31        9
# ...              ...       ...   ...   ...        ...      ...
# 1669848     0.005393       145   436  2489          6    72620
# 1669849     0.001827        36   692  2503          6    73041
# 1669850     0.004953        44   470  2519          6    73508
# 1669851     0.001163        29   684  2520          6    73541
# 1669852     0.003606        56   545  2556          6    74539
#
#          level_1_cell_type  level_2_cell_type      cell_type
# 0                   Immune     Myeloid_immune  M2_Macrophage
# 1                   Immune     Myeloid_immune  M2_Macrophage
# 2                   Immune     Myeloid_immune  M2_Macrophage
# 3                   Immune     Myeloid_immune  M2_Macrophage
# 4                   Immune     Myeloid_immune  M2_Macrophage
# ...                    ...                ...            ...
# 1669848             Immune     Myeloid_immune     Neutrophil
# 1669849             Immune     Myeloid_immune     Neutrophil
# 1669850             Immune     Myeloid_immune     Neutrophil
# 1669851             Immune     Myeloid_immune     Neutrophil
# 1669852             Immune     Myeloid_immune     Neutrophil
#
# [1669853 rows x 49 columns]

# %%
len(df2), len(df)

# %%
df['cell_type'].value_counts()

# %%
df['cell_type'] = df['cell_type'].replace({'CD4':'CD4+_T_cell', 'CD8': 'CD8+T_cell', 'M2':'M2_Macrophage', 'B':'B_cell','Other':'undefined', 'DC': 'Dendritic_cell',
                                           'Cytotoxic CD4':'Cytotoxic_CD4+_T_cell', 'Tumor': 'Cancer', 'NK':'NK_cell', 'M1':'M1_Macrophage',
                                           'Cytotoxic CD8':'Cytotoxic_CD8+_T_cell'})

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv', index=False)

# %% [markdown]
# # Implement different levels of granularity

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv')
df['cell_type'].value_counts()
# Out:
# cell_type
# CD4+_T_cell              457232
# CD8+_T_cell              254045
# M2_Macrophage            223290
# B_cell                   203862
# undefined                131420
# Dendritic_cell           113181
# Cytotoxic_CD4+_T_cell     70305
# Treg                      63262
# Cancer                    57917
# NK_cell                   29376
# Endothelial               24260
# Neutrophil                18490
# M1_Macrophage             13417
# Cytotoxic_CD8+_T_cell      9796
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# CD45                 float64
# CD20                 float64
# CD163                float64
# Histone H3           float64
# CD45RO               float64
# CD28                 float64
# CD153 (CD30L)        float64
# Lag3                 float64
# CD4                  float64
# CD11c                float64
# CD56                 float64
# FoxP3                float64
# GATA3                float64
# Granzyme B           float64
# PD-L1                float64
# CD16                 float64
# Ki-67                float64
# PD-1                 float64
# Pax-5                float64
# Tox                  float64
# CD161                float64
# CD68                 float64
# B2-Microglobulin     float64
# CD8                  float64
# CD3                  float64
# HLA1                 float64
# CD15                 float64
# Tbet                 float64
# CD14                 float64
# CXCR5                float64
# CD45RA               float64
# HLA-DR               float64
# CD57                 float64
# IL-10                float64
# CD30                 float64
# TIM3                 float64
# RORgT                float64
# TCRgd                float64
# CD86                 float64
# CD25                 float64
# Na-K ATPase          float64
# cellSize               int64
# x                      int64
# y                      int64
# identifier             int64
# cellLabel              int64
# level_1_cell_type     object
# level_2_cell_type     object
# cell_type             object
# dtype: object

# %%
df[['cellLabel', 'identifier']]
# Out:
#          cellLabel  identifier
# 0            26325          31
# 1                5          31
# 2                7          31
# 3                8          31
# 4                9          31
# ...            ...         ...
# 1669848      72620           6
# 1669849      73041           6
# 1669850      73508           6
# 1669851      73541           6
# 1669852      74539           6
#
# [1669853 rows x 2 columns]

# %%
df['cell_type'] = df['cell_type'].replace({'CD8+T_cell':'CD8+_T_cell'})
df['cell_type'].value_counts()

# %%
df['level_2_cell_type'] = df['cell_type']
df['level_2_cell_type'] = df['level_2_cell_type'].replace({'CD4+_T_cell':'Lymphoid_immune', 'CD8+_T_cell': 'Lymphoid_immune', 'M2_Macrophage':'Myeloid_immune', 'B_cell':'Lymphoid_immune',
                                                           'Dendritic_cell':'Myeloid_immune', 'Cytotoxic_CD4+_T_cell':'Lymphoid_immune', 'Treg':'Lymphoid_immune', 'NK_cell':'Lymphoid_immune',
                                                           'Endothelial':'Vascular', 'Neutrophil':'Myeloid_immune', 'M1_Macrophage':'Myeloid_immune', 'Cytotoxic_CD8+_T_cell':'Lymphoid_immune'})
df['level_2_cell_type'].value_counts()

# %%
df['level_1_cell_type'] = df['level_2_cell_type']
df['level_1_cell_type'] = df['level_1_cell_type'].replace({'Lymphoid_immune':'Immune', 'Myeloid_immune':'Immune', 'Vascular':'Stromal'})
df['level_1_cell_type'].value_counts()

# %%
df = reorder_columns(df, 'cell_type', 'level_1_cell_type')
df = reorder_columns(df, 'level_2_cell_type', 'level_1_cell_type')
df

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv', index=False)

# %% [markdown]
# # Encode uninfomrative variables

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv')
df.columns
# Out:
# Index(['CD45', 'CD20', 'CD163', 'Histone H3', 'CD45RO', 'CD28',
#        'CD153 (CD30L)', 'Lag3', 'CD4', 'CD11c', 'CD56', 'FoxP3', 'GATA3',
#        'Granzyme B', 'PD-L1', 'CD16', 'Ki-67', 'PD-1', 'Pax-5', 'Tox', 'CD161',
#        'CD68', 'B2-Microglobulin', 'CD8', 'CD3', 'HLA1', 'CD15', 'Tbet',
#        'CD14', 'CXCR5', 'CD45RA', 'HLA-DR', 'CD57', 'IL-10', 'CD30', 'TIM3',
#        'RORgT', 'TCRgd', 'CD86', 'CD25', 'Na-K ATPase', 'cellSize', 'x', 'y',
#        'sample_id', 'cell_id', 'level_1_cell_type', 'level_2_cell_type',
#        'cell_type'],
#       dtype='object')

# %%
df['sample_id'].unique()
# Out:
# array([31, 15, 19, 14,  3, 10, 18, 22, 11,  5, 20, 29, 23, 30,  9, 28,  8,
#        27,  7, 32, 26, 17,  4,  1, 24, 21, 25, 13, 16,  2, 12,  6])

# %%
df.dtypes
# Out:
# CD45                 float64
# CD20                 float64
# CD163                float64
# Histone H3           float64
# CD45RO               float64
# CD28                 float64
# CD153 (CD30L)        float64
# Lag3                 float64
# CD4                  float64
# CD11c                float64
# CD56                 float64
# FoxP3                float64
# GATA3                float64
# Granzyme B           float64
# PD-L1                float64
# CD16                 float64
# Ki-67                float64
# PD-1                 float64
# Pax-5                float64
# Tox                  float64
# CD161                float64
# CD68                 float64
# B2-Microglobulin     float64
# CD8                  float64
# CD3                  float64
# HLA1                 float64
# CD15                 float64
# Tbet                 float64
# CD14                 float64
# CXCR5                float64
# CD45RA               float64
# HLA-DR               float64
# CD57                 float64
# IL-10                float64
# CD30                 float64
# TIM3                 float64
# RORgT                float64
# TCRgd                float64
# CD86                 float64
# CD25                 float64
# Na-K ATPase          float64
# cellSize               int64
# x                      int64
# y                      int64
# sample_id              int64
# cell_id                int64
# level_1_cell_type     object
# level_2_cell_type     object
# cell_type             object
# dtype: object

# %%
df['identifier'].unique()
# Out:
# array([31, 15, 19, 14,  3, 10, 18, 22, 11,  5, 20, 29, 23, 30,  9, 28,  8,
#        27,  7, 32, 26, 17,  4,  1, 24, 21, 25, 13, 16,  2, 12,  6])

# %%
df = df.rename(columns={'cellLabel': 'cell_id', 'identifier': 'sample_id'})

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_1_MIBI_quantification.csv', index=False)
