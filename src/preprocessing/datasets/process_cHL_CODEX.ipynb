# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import anndata as ad

# %%
sc._settings.ScanpyConfig.n_jobs = -1

# %%
def z_score_normalization(data):
    return (data - np.mean(data, axis=0)) / np.std(data, axis=0)

def reorder_columns(df, col_changed, col_position) -> pd.DataFrame:
    """
    Reordering colums. The second input can either be an integer for index or it can be a reference column name. If reference column name is chosen, the column will be placed after the reference column.
    """
    if not isinstance(df, pd.DataFrame):
        raise ValueError("The first argument must be a pandas DataFrame")
    if not isinstance(col_changed, str):
        raise ValueError("The second argument must be a string representing a column name")
    if not isinstance(col_position, (str, int)):
        raise ValueError("The third argument must be either a string representing a column name or an integer representing a column index")
    if isinstance(col_position, int):
        cols = df.columns.tolist()
        if col_changed in cols and col_position <= len(cols) + 1:
            cols.remove(col_changed)
        
            index = col_position
            cols.insert(index, col_changed)
            
            df = df[cols]
    else:
        cols = df.columns.tolist()
        if col_changed in cols and col_position in cols:
            cols.remove(col_changed)
            index = cols.index(col_position)
            cols.insert(index+1, col_changed)
            
            df = df[cols]
    return df

# %%
df = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets2/cHL_CODEX/quantification/cHL_CODEX_annotation.csv')

# %%
df.columns

# %%
columns = df.columns.tolist()
new_order = columns[5:] + columns[:5]
df = df[new_order]
df.rename(columns={'cellType': 'cell_type'}, inplace=True)
df = reorder_columns(df, 'Y_cent', 'cellSize')
df = reorder_columns(df, 'X_cent', 'cellSize')
df.rename(columns={'X_cent': 'x', 'Y_cent': 'y'}, inplace=True)

# %%
df

# %%
df

# %%
df.to_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/cHL_CODEX_cleaned.csv', index=False)

# %%
X_columns = df.columns[:df.columns.get_loc('cellSize')]
obs_columns = df.columns[df.columns.get_loc('cellSize'):]
adata = ad.AnnData(
    X=df[X_columns],
    obs=df[obs_columns],
    var=pd.DataFrame(index=X_columns)
)
# Out:
# /Users/lukashat/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/anndata/utils.py:311: UserWarning: X converted to numpy array with dtype float64
#   warnings.warn(f"{name} converted to numpy array with dtype {arr.dtype}")
# /Users/lukashat/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.X.max()

# %%
sc.pp.neighbors(adata, n_neighbors=10)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='cell_type')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sc.pl.umap(adata, color='cell_type')
#
# File ~/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:686, in umap(adata, **kwargs)
#     627 @_wraps_plot_scatter
#     628 @_doc_params(
#     629     adata_color_etc=doc_adata_color_etc,
#    (...)
#     633 )
#     634 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     635     """Scatter plot in UMAP basis.
#     636
#     637     Parameters
#    (...)
#     684
#     685     """
# --> 686     return embedding(adata, "umap", **kwargs)
#
# File ~/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:144, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, marker, **kwargs)
#     141 check_projection(projection)
#     142 sanitize_anndata(adata)
# --> 144 basis_values = _get_basis(adata, basis)
#     145 dimensions = _components_to_dimensions(
#     146     components, dimensions, projection=projection, total_dims=basis_values.shape[1]
#     147 )
#     148 args_3d = dict(projection="3d") if projection == "3d" else {}
#
# File ~/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1169, in _get_basis(adata, basis)
#    1167 else:
#    1168     msg = f"Could not find {basis!r} or 'X_{basis}' in .obsm"
# -> 1169     raise KeyError(msg)
#
# KeyError: "Could not find 'umap' or 'X_umap' in .obsm"

# %%
sc.pl.matrixplot(adata, var_names=adata.var_names, groupby='cell_type', cmap='vlag', dendrogram=True, standard_scale='var')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_cell_type). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# NK cell CD11b and IDO1 do not make much sense

# %%
adata.obs['cell_type'].value_counts()

# %%
sc.tl.rank_genes_groups(adata, groupby='cell_type' , method='wilcoxon')

# %%
sc.tl.filter_rank_genes_groups(adata, min_in_group_fraction=0.2, max_out_group_fraction = 1, key = 'rank_genes_groups', key_added='rank_genes_groups_filtered')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=5, standard_scale='var', key='rank_genes_groups')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=5, standard_scale='var', key='rank_genes_groups_filtered')

# %% [markdown]
# ## Harmonize celltype labels

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv')
df2 = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_annotation.csv')

# %%
df

# %%
df['cell_type'].value_counts()

# %%
df['cell_type'] = df['cell_type'].replace({'CD4':'CD4+_T_cell', 'TReg':'Treg', 'B':'B_cell', 'M2':'M2_Macrophage', 'DC':'Dendritic_cell', 'CD8':'CD8+_T_cell',
                                           'Tumor':'Cancer', 'Cytotoxic CD8':'Cytotoxic_CD8+_T_cell','Mast':'Mast_cell', 'M1':'M1_Macrophage', 'NK':'NK_cell', 'Other':'unedfined'})

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv', index=False)

# %% [markdown]
# # Implement different levels of granularity

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv')
df['cell_type'].value_counts()

# %%
df['level_2_cell_type'] = df['cell_type']
df['level_2_cell_type'] = df['level_2_cell_type'].replace({'CD4+_T_cell':'Lymphoid_immune', 'CD8+_T_cell':'Lymphoid_immune', 'B_cell':'Lymphoid_immune', 'Dendritic_cell':'Myeloid_immune',
                                                           'Endothelial':'Vascular', 'NK_cell':'Lymphoid_immune', 'M2_Macrophage':'Myeloid_immune', 'Monocyte':'Myeloid_immune',
                                                           'Lymphatic':'Vascular', 'Neutrophil':'Myeloid_immune', 'Treg':'Lymphoid_immune', 'Mast_cell':'Myeloid_immune',
                                                           'M1_Macrophage':'Myeloid_immune', 'Cytotoxic_CD8+_T_cell':'Lymphoid_immune'})
df['level_2_cell_type'].value_counts()

# %%
df['level_1_cell_type'] = df['level_2_cell_type']
df['level_1_cell_type'] = df['level_1_cell_type'].replace({'Lymphoid_immune':'Immune', 'Myeloid_immune':'Immune', 'Vascular':'Stromal'})
df['level_1_cell_type'].value_counts()

# %%
df = reorder_columns(df, 'cell_type', 'level_1_cell_type')
df = reorder_columns(df, 'level_2_cell_type', 'level_1_cell_type')
df

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv', index=False)

# %% [markdown]
# # Encode uninfomrative variables

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv')
df.columns
# Out:
# Index(['BCL.2', 'CCR6', 'CD11b', 'CD11c', 'CD15', 'CD16', 'CD162', 'CD163',
#        'CD2', 'CD20', 'CD206', 'CD25', 'CD30', 'CD31', 'CD4', 'CD44', 'CD45RA',
#        'CD45RO', 'CD45', 'CD5', 'CD56', 'CD57', 'CD68', 'CD69', 'CD7', 'CD8',
#        'Collagen.4', 'Cytokeratin', 'DAPI.01', 'EGFR', 'FoxP3', 'Granzyme.B',
#        'HLA.DR', 'IDO.1', 'LAG.3', 'MCT', 'MMP.9', 'MUC.1', 'PD.1', 'PD.L1',
#        'Podoplanin', 'T.bet', 'TCR.g.d', 'TCRb', 'Tim.3', 'VISA', 'Vimentin',
#        'a.SMA', 'b.Catenin', 'cell_id', 'cellSize', 'x', 'y',
#        'level_1_cell_type', 'level_2_cell_type', 'cell_type'],
#       dtype='object')

# %%
df['cell_type'].value_counts()
# Out:
# cell_type
# CD4+_T_cell              37480
# CD8+_T_cell              17184
# B_cell                   16196
# Dendritic_cell            9637
# Endothelial               8705
# Cancer                    8260
# NK_cell                   7339
# M2_Macrophage             7286
# Monocyte                  6913
# unedfined                 5108
# Lymphatic                 3768
# Neutrophil                3442
# Treg                      3352
# Mast_cell                 3324
# M1_Macrophage             3101
# Epithelial                2251
# Seg Artifact              1431
# Cytotoxic_CD8+_T_cell      384
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# BCL.2                float64
# CCR6                 float64
# CD11b                float64
# CD11c                float64
# CD15                 float64
# CD16                 float64
# CD162                float64
# CD163                float64
# CD2                  float64
# CD20                 float64
# CD206                float64
# CD25                 float64
# CD30                 float64
# CD31                 float64
# CD4                  float64
# CD44                 float64
# CD45RA               float64
# CD45RO               float64
# CD45                 float64
# CD5                  float64
# CD56                 float64
# CD57                 float64
# CD68                 float64
# CD69                 float64
# CD7                  float64
# CD8                  float64
# Collagen.4           float64
# Cytokeratin          float64
# DAPI.01              float64
# EGFR                 float64
# FoxP3                float64
# Granzyme.B           float64
# HLA.DR               float64
# IDO.1                float64
# LAG.3                float64
# MCT                  float64
# MMP.9                float64
# MUC.1                float64
# PD.1                 float64
# PD.L1                float64
# Podoplanin           float64
# T.bet                float64
# TCR.g.d              float64
# TCRb                 float64
# Tim.3                float64
# VISA                 float64
# Vimentin             float64
# a.SMA                float64
# b.Catenin            float64
# cell_id                int64
# cellSize               int64
# x                      int64
# y                      int64
# level_1_cell_type     object
# level_2_cell_type     object
# cell_type             object
# dtype: object

# %%
df['cellLabel']
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 145156    152811
# 145157    152812
# 145158    152813
# 145159    152814
# 145160    152815
# Name: cellLabel, Length: 145161, dtype: int64

# %%
df = df.rename(columns={'cellLabel': 'cell_id'})

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv', index=False)

# %% [markdown]
# # Bin some celltypes

# %%
df = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv')
df['cell_type'].value_counts()
# Out:
# cell_type
# CD4+_T_cell              37480
# CD8+_T_cell              17184
# B_cell                   16196
# Dendritic_cell            9637
# Endothelial               8705
# Cancer                    8260
# NK_cell                   7339
# M2_Macrophage             7286
# Monocyte                  6913
# undefined                 6539
# Lymphatic                 3768
# Neutrophil                3442
# Treg                      3352
# Mast_cell                 3324
# M1_Macrophage             3101
# Epithelial                2251
# Cytotoxic_CD8+_T_cell      384
# Name: count, dtype: int64

# %%
df['level_2_cell_type'] = df['level_2_cell_type'].replace({'Seg Artifact':'undefined', 'unedfined':'undefined'})
df['level_1_cell_type'] = df['level_1_cell_type'].replace({'Seg Artifact':'undefined', 'undefined':'undefined'})
df['cell_type'] = df['cell_type'].replace({'Seg Artifact':'undefined', 'unedfined':'undefined'})
df['cell_type'].value_counts()
# Out:
# cell_type
# CD4+_T_cell              37480
# CD8+_T_cell              17184
# B_cell                   16196
# Dendritic_cell            9637
# Endothelial               8705
# Cancer                    8260
# NK_cell                   7339
# M2_Macrophage             7286
# Monocyte                  6913
# undefined                 6539
# Lymphatic                 3768
# Neutrophil                3442
# Treg                      3352
# Mast_cell                 3324
# M1_Macrophage             3101
# Epithelial                2251
# Cytotoxic_CD8+_T_cell      384
# Name: count, dtype: int64

# %%
df.to_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/datasets/cHL_CODEX_quantification.csv', index=False)
